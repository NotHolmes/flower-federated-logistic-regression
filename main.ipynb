# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import utils
import numpy as np

# %%
df = pd.read_csv('dataset/train.csv')
df
# Out:
#        Unnamed: 0   Age  Annual_Income  Monthly_Inhand_Salary  \
# 0               0  23.0       19114.12            1824.843333
# 1               1  23.0       19114.12            1824.843333
# 2               2  33.0       19114.12            1824.843333
# 3               3  23.0       19114.12            1824.843333
# 4               4  23.0       19114.12            1824.843333
# ...           ...   ...            ...                    ...
# 79997       79997  52.0       93589.48            7895.123333
# 79998       79998  52.0       93589.48            7895.123333
# 79999       79999  52.0       93589.48            7895.123333
# 80000       80000  33.0       36115.92            2716.660000
# 80001       80001  39.0       36115.92            2716.660000
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                    3.0              4.0            3.0          4.0
# 1                    3.0              4.0            3.0          4.0
# 2                    3.0              4.0            3.0          4.0
# 3                    3.0              4.0            3.0          4.0
# 4                    3.0              4.0            3.0          4.0
# ...                  ...              ...            ...          ...
# 79997                6.0              7.0           16.0          3.0
# 79998                6.0              7.0           16.0          3.0
# 79999                6.0              7.0           16.0          3.0
# 80000                0.0              7.0            9.0          3.0
# 80001                0.0              7.0            9.0          3.0
#
#        Delay_from_due_date  Num_of_Delayed_Payment  ...  Occupation_Musician  \
# 0                      3.0                     7.0  ...                False
# 1                     -1.0                     7.0  ...                False
# 2                      3.0                     7.0  ...                False
# 3                      5.0                     4.0  ...                False
# 4                      6.0                     7.0  ...                False
# ...                    ...                     ...  ...                  ...
# 79997                 24.0                    17.0  ...                False
# 79998                 24.0                    17.0  ...                False
# 79999                 24.0                    17.0  ...                False
# 80000                 11.0                     3.0  ...                False
# 80001                 11.0                     6.0  ...                False
#
#        Occupation_Scientist  Occupation_Teacher  Occupation_Writer  \
# 0                      True               False              False
# 1                      True               False              False
# 2                      True               False              False
# 3                      True               False              False
# 4                      True               False              False
# ...                     ...                 ...                ...
# 79997                 False               False               True
# 79998                 False               False               True
# 79999                 False               False               True
# 80000                 False               False              False
# 80001                 False               False              False
#
#        Payment_of_Min_Amount_Yes  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 79997                      False
# 79998                      False
# 79999                      False
# 80000                      False
# 80001                      False
#
#        Payment_Behaviour_High_spent_Medium_value_payments  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                   True
# ...                                                  ...
# 79997                                              False
# 79998                                              False
# 79999                                              False
# 80000                                              False
# 80001                                              False
#
#        Payment_Behaviour_High_spent_Small_value_payments  \
# 0                                                   True
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 79997                                              False
# 79998                                              False
# 79999                                              False
# 80000                                               True
# 80001                                              False
#
#        Payment_Behaviour_Low_spent_Large_value_payments  \
# 0                                                 False
# 1                                                  True
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 79997                                             False
# 79998                                             False
# 79999                                             False
# 80000                                             False
# 80001                                             False
#
#        Payment_Behaviour_Low_spent_Medium_value_payments  \
# 0                                                  False
# 1                                                  False
# 2                                                   True
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 79997                                               True
# 79998                                              False
# 79999                                              False
# 80000                                              False
# 80001                                               True
#
#        Payment_Behaviour_Low_spent_Small_value_payments
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                  True
# 4                                                 False
# ...                                                 ...
# 79997                                             False
# 79998                                              True
# 79999                                              True
# 80000                                             False
# 80001                                             False
#
# [80002 rows x 55 columns]

# %%
len(df.columns)
# Out:
# 55

# %%
X_train, X_test, y_train, y_test = utils.load_dataset('dataset/train.csv')

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=1)
