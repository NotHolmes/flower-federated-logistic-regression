# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import utils
from joblib import load
import numpy as np

# %%
X_train, X_test, y_train, y_test = utils.load_dataset("dataset/test.csv")

# %%
model = load('model/model.joblib')

# %%
X_test, _ = utils.scale_data(X_test, X_test)

# %%
model.score(X_test, y_test)
# Out:
# /Users/holmes/Documents/Documents - Zahil’s Laptop/School/Project_2/flower-federated-project/venv/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# 0.651
